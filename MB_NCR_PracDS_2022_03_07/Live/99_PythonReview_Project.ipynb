# %% [markdown]
# # Python Review Project

# %% [markdown]
# ## Project Brief
#
# Either use the FBI Wanted API response below, as provided, or choose a detailed API from the https://github.com/public-apis/public-apis list.
#
# By processing the data in this response, produce a report which summarises they key elements.
#
# * Preferably include,
#     * averages of some numerical data
#         * HINT: `from statistics import mean, median, mode`
#         * HINT: `import statistics`, `statistics.stdev()`
#     * a mode of some categorical data (eg., text data)
#     * use if/elif/else to make some decisions based on values which are present
# * STRETCH:
#     * include error handling
#     * include functions
#         * eg., a function which makes a decision based on input
#         * `def decide(value): if return .../else return ....`

# %% [markdown]
# ---

# %% [markdown]
# ### EXAMPLE: FBI Wanted API

# %% [markdown]
# https://www.fbi.gov/wanted/api

# %%
import requests

query = {
    'field_offices': 'miami'
}

response = requests.get('https://api.fbi.gov/wanted/v1/list', params=query)

# %%
response.json()
# Out:
# {'total': 33,
#  'items': [{'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Korea',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['Kidnappings and Missing Persons'],
#    'languages': None,
#    'sex': 'Female',
#    'eyes': 'brown',
#    'caution': None,
#    'ncic': None,
#    'url': 'https://www.fbi.gov/wanted/kidnap/haneul-oh',
#    'age_max': None,
#    'path': '/wanted/kidnap/haneul-oh',
#    'possible_countries': None,
#    'description': 'December 20, 2021\r\nDavie, Florida',
#    'coordinates': [],
#    'remarks': '<p>Haneul Oh has ties to\xa0New Jersey; Baltimore, Maryland; and Korea.\xa0\xa0She is a Korean National living and studying in the United States.</p>',
#    'height_max': 60,
#    'eyes_raw': 'Brown',
#    'uid': 'f1a6d821a6da40f5bb718b7ad844fb29',
#    'age_range': None,
#    'nationality': 'Korean',
#    'dates_of_birth_used': ['January 28, 2000'],
#    'reward_text': None,
#    'aliases': None,
#    'height_min': 60,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/download.pdf'},
#     {'name': '한국어로',
#      'url': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/ohkorean.pdf/@@download/file/ohkorean.pdf'}],
#    'race_raw': 'Asian',
#    'weight_min': 105,
#    'modified': '2022-02-22T12:59:28+00:00',
#    'legat_names': None,
#    'title': 'HANEUL OH',
#    'weight': '105 pounds',
#    'publication': '2022-02-10T09:51:00',
#    'status': 'na',
#    'race': 'asian',
#    'hair': 'black',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Black',
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/@@images/image/large',
#      'caption': None},
#     {'original': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/ohcar.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/ohcar.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/kidnap/haneul-oh/ohcar.jpg/@@images/image/large',
#      'caption': "Oh's Car"}],
#    'complexion': None,
#    'weight_max': 105,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': '<p>Haneul Oh was last seen on December 20, 2021, in Davie, Florida.\xa0 Her disappearance occurred under suspicious circumstances.\xa0 She is known to drive a\xa02005 Toyota Corolla, gray in color, with New Jersey license plates reading L20NAZ.</p>\r\n<p>\xa0</p>',
#    '@id': 'https://api.fbi.gov/@wanted-person/f1a6d821a6da40f5bb718b7ad844fb29'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Ecuador',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'blue',
#    'caution': '<p>Fernando Grijalva is wanted for allegedly embezzling over $3 million while working for a subsidiary of a multibillion dollar company, in Boca Raton, Florida. The subsidiary purchased computer supplies and equipment, and sold these products to various distributors. From 2002 through 2003, while head of accounts payable for this company, Grijalva allegedly issued fraudulent invoices under the name of a bogus company that he created.</p>\r\n<p>\xa0</p>\r\n<p>On December 12, 2003, a complaint was filed by the United States Magistrate, United States District Court, Southern District of Florida, charging Grijalva with mail fraud and bank fraud, and a federal warrant was issued for his arrest.</p>\r\n<p>\xa0</p>\r\n<p>Grijalva is also wanted by local law enforcement authorities in Florida for violating his probation which followed an unrelated charge for grand theft in 2001.</p>\r\n<p>\xa0</p>',
#    'ncic': 'W275271957',
#    'url': 'https://www.fbi.gov/wanted/wcc/fernando-grijalva',
#    'age_max': None,
#    'path': '/wanted/wcc/fernando-grijalva',
#    'possible_countries': None,
#    'description': 'Mail Fraud; Bank Fraud',
#    'coordinates': [],
#    'remarks': '<p>Grijalva may travel to Las Vegas, Nevada, or Miami, Florida. Grijalva is believed to be in Ecuador.</p>',
#    'height_max': 72,
#    'eyes_raw': 'Blue',
#    'uid': '9badeee26b4517d1c9071df85daf2653',
#    'age_range': None,
#    'nationality': 'Ecuadoran',
#    'dates_of_birth_used': ['March 26, 1975'],
#    'reward_text': None,
#    'aliases': ['Fernando Grijalva Cepeda'],
#    'height_min': 72,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/fernando-grijalva/download.pdf'},
#     {'name': 'EN ESPAÑOL',
#      'url': 'https://www.fbi.gov/wanted/wcc/fernando-grijalva/grijalvaspanish.pdf/@@download/file/grijalvaSpanish.pdf'}],
#    'race_raw': 'White (Hispanic)',
#    'weight_min': 220,
#    'modified': '2021-11-22T12:31:58+00:00',
#    'legat_names': None,
#    'title': 'FERNANDO GRIJALVA',
#    'weight': '220 pounds',
#    'publication': '2010-08-17T17:30:00',
#    'status': 'na',
#    'race': 'hispanic',
#    'hair': 'brown',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Brown',
#    'occupations': ['Businessman'],
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/fernando-grijalva/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/fernando-grijalva/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/fernando-grijalva/@@images/image/large',
#      'caption': 'Photograph taken in 2001'}],
#    'complexion': None,
#    'weight_max': 220,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/9badeee26b4517d1c9071df85daf2653'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'La Calera, Chile',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['Additional Violent Crimes'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': '<p>Mauro Ociel Valenzuela-Reyes is wanted for his alleged involvement in the crash of ValuJet Airlines Flight 592 in 1996.</p>\r\n<p>\xa0</p>\r\n<p>On May 11, 1996, Flight 592 crashed in the Florida Everglades, killing all 110 people on board. Investigation led to the indictment of an aircraft repair facility in Florida, and three of its employees, in connection with improperly packaged chemical oxygen generators that were loaded on Flight 592 and signed off by company employees despite lacking safety caps. Valenzuela-Reyes is the final employee wanted in connection with this incident.</p>\r\n<p>\xa0</p>\r\n<p>On April 6, 2000, a federal arrest warrant was issued for Valenzuela-Reyes in the United States District Court, Southern District of Florida, after he was charged with disobedience and resistance to lawful order and command of the United States District Court for the Southern District of Florida, and failure to appear for trial. Valenzuela-Reyes was previously charged on July 13, 1999, with conspiracy to make false statements to the Federal Aviation Administration and the Department of Transportation; false statements to the Federal Aviation Administration and the Department of Transportation; and causing the transportation of hazardous material.</p>',
#    'ncic': 'W860126244',
#    'url': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes',
#    'age_max': None,
#    'path': '/wanted/additional/mauro-ociel-valenzuela-reyes',
#    'possible_countries': None,
#    'description': 'Disobedience and Resistance to Lawful Order and Command of the United States District Court for the Southern District of Florida; Failure to Appear for Trial; Conspiracy to Make False Statements to the Federal Aviation Administration and the Department of Transportation; False statements to the Federal Aviation Administration and the Department of Transportation; Causing the Transport of Hazardous Materials',
#    'coordinates': [],
#    'remarks': '<p>Valenzuela-Reyes may be living under a false identity.</p>\r\n<p>\xa0</p>\r\n<p>He may be in Chile and may travel to Peru, Argentina, Brazil, and Bolivia, and other South American countries. He has ties to Georgia in the United States of America.</p>',
#    'height_max': 72,
#    'eyes_raw': 'Brown',
#    'uid': '49c18e556a424e7a8d5fa12b59a04405',
#    'age_range': None,
#    'nationality': None,
#    'dates_of_birth_used': ['April 18, 1969'],
#    'reward_text': 'The FBI is offering a reward of up to $10,000 for information leading to the location and capture of Mauro Ociel Valenzuela-Reyes.',
#    'aliases': ['Mauro Valenzuela-Reyes',
#     'Mauro Valenzuela',
#     'Mauro O. Valenzuela',
#     'Mauro Ociel Valenzuela',
#     'Reyes Mauro Valenzuela',
#     'Mauro Valenzvela-Reyes',
#     'Mauro Reyes'],
#    'height_min': 70,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/download.pdf'},
#     {'name': 'EM PORTUGUÊS',
#      'url': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/vr-portuguese.pdf/@@download/file/VR portuguese.pdf'},
#     {'name': 'AUF DEUTSCH',
#      'url': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/vr-german.pdf/@@download/file/VR German.pdf'},
#     {'name': 'EN ESPAÑOL',
#      'url': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/mauro-ociel-valenzuela-reyes-en-espanol.pdf/@@download/file/Mauro Ociel Valenzuela Reyes EN ESPAÑOL.pdf'}],
#    'race_raw': 'White (Hispanic)',
#    'weight_min': 170,
#    'modified': '2021-11-16T15:04:23+00:00',
#    'legat_names': None,
#    'title': 'MAURO OCIEL VALENZUELA-REYES',
#    'weight': '170 pounds',
#    'publication': '2017-06-09T14:33:00',
#    'status': 'na',
#    'race': 'hispanic',
#    'hair': 'black',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Black',
#    'occupations': ['Airframe and power plant (A&P) mechanic; former Federal Aviation Administration certified aircraft mechanic'],
#    'images': [{'original': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/@@images/image/large',
#      'caption': 'Photograph taken in 1996'},
#     {'original': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/valenzuela-2.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/valenzuela-2.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/valenzuela-2.jpg/@@images/image/large',
#      'caption': 'Photograph age-progressed to age 48'},
#     {'original': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/valenzuela-3.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/valenzuela-3.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/additional/mauro-ociel-valenzuela-reyes/valenzuela-3.jpg/@@images/image/large',
#      'caption': 'Photograph age-progressed to age 48'}],
#    'complexion': None,
#    'weight_max': 170,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/49c18e556a424e7a8d5fa12b59a04405'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Virginia',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['Domestic Terrorism'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': '<p>George Edward Wright is wanted for his involvement in a series of crimes dating back to 1962.</p>\r\n<p>\xa0</p>\r\n<p>On November 23, 1962, Wright and an accomplice, who was arrested,\xa0shot and killed the owner of a\xa0gas station in Wall, New Jersey, during the commission of a robbery at the business.\xa0 On December 13, 1962, Wright was indicted for the murder.\xa0 He entered a plea of "no defense", and was sentenced to prison for a period of 15 to 30 years.\xa0 Then, on August 22, 1970, Wright escaped from the New Jersey State Prison in Leesburg, New Jersey.\xa0 The State of New Jersey issued an arrest warrant for Wright after he was charged with escape and, on August 26, 1970, a federal arrest warrant was issued for Wright in the United States District Court, District of New Jersey, Trenton, New Jersey, after he was charged with unlawful flight to avoid confinement.</p>\r\n<p>\xa0</p>\r\n<p>On July 31, 1972, Wright, and others who were arrested, hijacked a Delta Airlines jet en route from Detroit, Michigan, to Miami, Florida.\xa0 The hijackers used handguns and made threats against the passengers on the plane.\xa0 At the time, Wright used the name Reverend Larry Burgess, wore\xa0the clothing\xa0of a cleric, and carried a Bible.\xa0 He used a gun concealed in the Bible to confront the aircraft\'s pilot and crew.\xa0 After a ransom was delivered to the hijackers, the passengers were released in Miami.\xa0 The hijackers and the plane\'s crew then flew to Boston, Massachusetts, refueled, picked up an international navigator, and flew to Algiers.\xa0 The plane and ransom were then returned to the United States Government,\xa0while the hijackers remained free.</p>\r\n<p>\xa0</p>\r\n<p>On September 26, 2011, after more than 40 years as a fugitive, Wright was arrested in Portugal.\xa0 He was released from custody in October of 2011, and remains in Portugal, where he continues to live.\xa0 Wright\xa0is the sole hijacker to remain at large.</p>',
#    'ncic': 'W244803836',
#    'url': 'https://www.fbi.gov/wanted/dt/george-edward-wright',
#    'age_max': None,
#    'path': '/wanted/dt/george-edward-wright',
#    'possible_countries': None,
#    'description': 'Unlawful Flight to Avoid Confinement - Escape (Murder); Air Piracy (Seizing by Force an Aircraft in Air Commerce); Aiding and Abetting',
#    'coordinates': [],
#    'remarks': '<p>Wright is known to be living in Portugal.</p>',
#    'height_max': 72,
#    'eyes_raw': 'Brown',
#    'uid': 'fcf75675bc66432c82f3304db19fb6e8',
#    'age_range': None,
#    'nationality': 'American',
#    'dates_of_birth_used': ['March 29, 1943',
#     'October 4, 1950',
#     'November 11, 1950'],
#    'reward_text': None,
#    'aliases': ['George E. Wright',
#     'George Wright',
#     'Larry Burgess',
#     'Larry Darnell Burgess',
#     'Reverend L. Burgess',
#     'Reverend Burgess',
#     'Jack Ragland'],
#    'height_min': 71,
#    'scars_and_marks': 'Wright has scars on his head, left cheek, and near his right eye.  He also has a burn scar on his upper left forearm.',
#    'possible_states': None,
#    'field_offices': ['miami', 'newark'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/dt/george-edward-wright/download.pdf'},
#     {'name': 'EM PORTUGUÊS',
#      'url': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wrightportuguese.pdf/@@download/file/wrightportuguese.pdf'}],
#    'race_raw': 'Black',
#    'weight_min': 160,
#    'modified': '2021-11-16T15:03:51+00:00',
#    'legat_names': None,
#    'title': 'GEORGE EDWARD WRIGHT',
#    'weight': '160 to 170 pounds',
#    'publication': '2017-07-26T13:51:00',
#    'status': 'na',
#    'race': 'black',
#    'hair': 'black',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Black',
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/@@images/image/large',
#      'caption': 'Photograph taken in 2011'},
#     {'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright1962.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright1962.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright1962.jpg/@@images/image/large',
#      'caption': 'Photograph taken in 1962'},
#     {'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011d.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011d.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011d.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011f.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011f.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011f.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011b.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011b.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011b.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011c.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011c.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011c.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011e.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011e.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/dt/george-edward-wright/wright2011e.jpg/@@images/image/large',
#      'caption': ''}],
#    'complexion': None,
#    'weight_max': 170,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': 'SHOULD BE CONSIDERED ARMED AND DANGEROUS',
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/fcf75675bc66432c82f3304db19fb6e8'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': None,
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['Seeking Information'],
#    'languages': None,
#    'sex': None,
#    'eyes': None,
#    'caution': None,
#    'ncic': None,
#    'url': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney',
#    'age_max': None,
#    'path': '/wanted/seeking-info/drew-devoursney',
#    'possible_countries': ['BLZ'],
#    'description': 'April 25, 2017\r\nCorozal, Belize',
#    'coordinates': [],
#    'remarks': None,
#    'height_max': None,
#    'eyes_raw': None,
#    'uid': '8fb54cb943b14da692eaca056da683f1',
#    'age_range': None,
#    'nationality': 'American',
#    'dates_of_birth_used': ['February 5, 1981'],
#    'reward_text': '"The FBI is offering a reward of up to $10,000 USD for information leading directly to an arrest for the murder of United States citizen Drew Devoursney.',
#    'aliases': None,
#    'height_min': None,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney/download.pdf'}],
#    'race_raw': 'White',
#    'weight_min': None,
#    'modified': '2021-11-16T15:02:57+00:00',
#    'legat_names': None,
#    'title': 'DREW DEVOURSNEY',
#    'weight': None,
#    'publication': '2018-12-21T07:20:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': None,
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': None,
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney/@@images/image/large',
#      'caption': 'Drew Devoursney'},
#     {'original': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney/francesca-matus-pic.png',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney/francesca-matus-pic.png/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/drew-devoursney/francesca-matus-pic.png/@@images/image/large',
#      'caption': 'Francesca Matus'}],
#    'complexion': None,
#    'weight_max': None,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': '<p>Drew Devoursney was last seen leaving Scotty’s Bar in Corozal, Belize on April 25, 2017, with his Canadian girlfriend Francesca Matus. Drew and Francesca were found murdered on May 1, 2017, in Corozal.</p>',
#    '@id': 'https://api.fbi.gov/@wanted-person/8fb54cb943b14da692eaca056da683f1'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Glasgow, Scotland, United Kingdom',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'hazel',
#    'caution': '<p>James Alexander Ward is wanted for his alleged involvement in a precious metals fraud scheme that operated in Florida from September of 2007 to March of 2010.</p>\r\n<p>\xa0</p>\r\n<p>Ward allegedly operated an entity called Kastle &amp; Hawk, Inc., which solicited investors to buy precious metals such as gold, silver, and platinum on a leveraged basis. Instead of investing the approximately $400,000 Ward received from at least 12 investors, Ward allegedly used the money for his own personal use and benefit. No precious metals were ever acquired for investors.</p>\r\n<p>\xa0</p>\r\n<p>A federal arrest warrant was issued for Ward in the United States District Court, Southern District of Florida, Miami, Florida, on September 6, 2012, after he was charged with wire fraud.</p>',
#    'ncic': 'W565779415',
#    'url': 'https://www.fbi.gov/wanted/wcc/james-alexander-ward',
#    'age_max': None,
#    'path': '/wanted/wcc/james-alexander-ward',
#    'possible_countries': None,
#    'description': 'Wire Fraud',
#    'coordinates': [],
#    'remarks': '<p>Ward may travel within the United Kingdom, to include England, Scotland, Wales, and Northern Ireland. He may also travel to Canada and Mexico.</p>\r\n<p>\xa0</p>\r\n<p>He has previously resided in Miami Beach, Florida.</p>',
#    'height_max': 68,
#    'eyes_raw': 'Hazel',
#    'uid': 'c9d03ee2fa9d4b38987d9a1f7d8effe4',
#    'age_range': None,
#    'nationality': 'Scottish',
#    'dates_of_birth_used': ['April 27, 1953'],
#    'reward_text': None,
#    'aliases': ['James Ward', 'James A. Ward', 'Jamie D. Ward'],
#    'height_min': 68,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/james-alexander-ward/download.pdf'}],
#    'race_raw': 'White',
#    'weight_min': 150,
#    'modified': '2021-11-16T15:02:31+00:00',
#    'legat_names': None,
#    'title': 'JAMES ALEXANDER WARD',
#    'weight': '150 to 155 pounds',
#    'publication': '2018-08-07T09:10:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': 'blond',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Blond - may change his hair color frequently',
#    'occupations': ['Securities Broker'],
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/james-alexander-ward/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/james-alexander-ward/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/james-alexander-ward/@@images/image/large',
#      'caption': 'Photograph taken in 2018'}],
#    'complexion': None,
#    'weight_max': 155,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/c9d03ee2fa9d4b38987d9a1f7d8effe4'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': None,
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['Seeking Information'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': None,
#    'ncic': None,
#    'url': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen',
#    'age_max': None,
#    'path': '/wanted/seeking-info/kenneth-knute-haugen',
#    'possible_countries': ['DOM'],
#    'description': 'Missing Person/Victim\r\nPort of Luperon, Dominican Republic\r\nApril 5, 2017',
#    'coordinates': [],
#    'remarks': None,
#    'height_max': 69,
#    'eyes_raw': 'Brown',
#    'uid': 'ed4aaf8f0d5e41d9b06b56e8ec9f52b4',
#    'age_range': None,
#    'nationality': None,
#    'dates_of_birth_used': ['January 20, 1945'],
#    'reward_text': 'The FBI is offering a reward of up to $10,000 USD for information leading directly to the arrest of the person(s) involved in the disappearance/murder of United States citizen Kenneth Knute Haugen.',
#    'aliases': ['Ken Haugen'],
#    'height_min': 69,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen/download.pdf'}],
#    'race_raw': 'White',
#    'weight_min': 190,
#    'modified': '2021-11-16T15:02:20+00:00',
#    'legat_names': ['americas-10'],
#    'title': 'KENNETH KNUTE HAUGEN',
#    'weight': '190 pounds',
#    'publication': '2019-02-28T10:39:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': 'brown',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Brown and Grey',
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen/@@images/image/large',
#      'caption': 'Photo taken circa 2014'},
#     {'original': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen/imagen-kenneth-knute-haugen-2019-02-28-13-17-2-20190228131914.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen/imagen-kenneth-knute-haugen-2019-02-28-13-17-2-20190228131914.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/kenneth-knute-haugen/imagen-kenneth-knute-haugen-2019-02-28-13-17-2-20190228131914.jpg/@@images/image/large',
#      'caption': ''}],
#    'complexion': None,
#    'weight_max': 190,
#    'person_classification': 'Victim',
#    'build': None,
#    'warning_message': None,
#    'details': '<p>Kenneth Haugen was last seen on April 5, 2017, getting off a catamaran named the San Marlot, which was anchored at the Port of Luperon in the Dominican Republic. Haugen had recently sold the catamaran to another United States citizen. Haugen was reported missing on April 6, 2017, when his vehicle, a black Honda Civic, was found with the doors unlocked and the keys still in the vehicle near the beach in Luperon, less than a mile from where he lived. This area is also known as "La Playita La Rusia".\xa0\xa0</p>\r\n<p>\xa0</p>',
#    '@id': 'https://api.fbi.gov/@wanted-person/ed4aaf8f0d5e41d9b06b56e8ec9f52b4'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': None,
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': [],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': None,
#    'ncic': None,
#    'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901',
#    'age_max': 35,
#    'path': '/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901',
#    'possible_countries': None,
#    'description': 'July 19, 1994\r\nPanama',
#    'coordinates': [],
#    'remarks': None,
#    'height_max': 69,
#    'eyes_raw': 'Light brown',
#    'uid': 'dfc16386d75e44c58239c4e858ac0e16',
#    'age_range': 'Approximately 25 to 35 years old (at the time of the bombing)',
#    'nationality': None,
#    'dates_of_birth_used': None,
#    'reward_text': None,
#    'aliases': ['Unknown'],
#    'height_min': 69,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/download.pdf'},
#     {'name': 'EN ESPAÑOL',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/alas-bombing-poster-spanish-1.pdf/@@download/file/Alas Bombing Poster (Spanish).pdf'}],
#    'race_raw': 'White (Middle Eastern)',
#    'weight_min': 180,
#    'modified': '2021-11-16T14:59:48+00:00',
#    'legat_names': None,
#    'title': 'Bombing of Alas Chiricanas Airlines Flight 00901',
#    'weight': 'Approximately 180 pounds',
#    'publication': '2019-06-19T10:02:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': 'black',
#    'age_min': 25,
#    'suspects': None,
#    'hair_raw': 'Black',
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/@@images/image/large',
#      'caption': None},
#     {'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/alas-pic-3.png',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/alas-pic-3.png/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/alas-pic-3.png/@@images/image/large',
#      'caption': 'Unidentified Middle Eastern Males'},
#     {'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/alas-pic-2.png',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/alas-pic-2.png/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal/bombing-of-alas-chircanas-airlines-flight-00901/alas-pic-2.png/@@images/image/large',
#      'caption': ''}],
#    'complexion': 'Light',
#    'weight_max': 180,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': "<p>The FBI is seeking information on the bombing of Alas Chiricanas Airlines Flight 00901 on July 19, 1994, or any of the suspicious activity described.</p>\r\n<p>\xa0</p>\r\n<p>At approximately 4:30 p.m. Central Daylight Time (CDT), Flight 00901 departed from France Field, Colón, Panama, with a destination of Panama City, Panama. The flight exploded shortly after takeoff, killing all 21 people on board. Authorities are seeking information that may pertain to possible suspect(s) and the crime that occurred aboard this flight. All deceased passengers and crew in the Flight 00901 crash were claimed, except one. A body has possibly been identified as Ali Hawa Jamal. He is suspected of carrying the bomb aboard the aircraft.</p>\r\n<p>\xa0</p>\r\n<p>According to reports, an unidentified Middle Eastern male used the stolen credit card of a US citizen to rent a Mazda 4x4 at a Vantage Rent-a-Car located in Panama City, Panama, on May 27, 1994. The next day the same unidentified individual called the car rental agency and stated he wanted to rent a second car, a Jeep Cherokee 4x4, as his friend was using the initial car that was rented. The individual charged both cars to the stolen credit card. Both cars were later found abandoned near Tocumen Airport in Panama City, Panama.\xa0\xa0</p>\r\n<p>\xa0</p>\r\n<p>On\xa0 May 28, 1994,\xa0 it was further reported that possibly the same Middle Eastern male utilizing the same stolen credit card, purchased a two-line telephone system from a Panamanian business. Ali Hawa Jamal had a Motorola Radio P-500 radio with him during the ill-fated flight of Alas Chiricanas Airlines Flight 00901.</p>\r\n<p>\xa0</p>\r\n<p>It is unknown if the unknown Middle Eastern males were associates of Ali Hawa Jamal. The unknown males are believed to have traveled to Colombia, Venezuela, Costa Rica and Lebanon. It is suspected that the Middle Eastern males were in contact with individuals in the region that has been linked to weapons traffickers. The Sidon, Lebanon based terrorist group Ansar Allah expressed support for the bombing through multiple media outlets. It is suspected that the attack was linked\xa0 to a terrorist group or groups allied with Ansar Allah's political beliefs.</p>",
#    '@id': 'https://api.fbi.gov/@wanted-person/dfc16386d75e44c58239c4e858ac0e16'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Los Angeles, California',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': '<p>Roda Abdulhassan Taher is wanted for his alleged actions as the leader of a global money laundering organization that engaged in money laundering and transactions in criminally derived property in the United States (primarily Florida) and overseas. Working from Beirut, Lebanon, Taher was allegedly personally responsible for the theft and transfer of more than $94 million U.S. Dollars (USD) from the elderly and otherwise vulnerable victims around the world.</p>\r\n<p>\xa0</p>\r\n<p>A federal arrest warrant was issued for Taher in the United States District Court for the Southern District of Florida, Miami, Florida, on September 28, 2017, after he was charged with conspiracy to commit money laundering, conspiracy to commit bank fraud, 21 counts of money laundering, and 18 counts of transactions in criminally derived property.</p>',
#    'ncic': 'W103912496',
#    'url': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher',
#    'age_max': None,
#    'path': '/wanted/wcc/roda-abdulhassan-taher',
#    'possible_countries': None,
#    'description': 'Conspiracy to Commit Money Laundering; Conspiracy to Commit Bank Fraud; Money Laundering (21 counts); Transactions in Criminally Derived Property (18 counts)',
#    'coordinates': [],
#    'remarks': '<p>Taher may travel to Nigeria; Sierra Leone; Lebanon; Boston, Massachusetts; and Farmington Hills or Detroit, Michigan.</p>\r\n<p>\xa0</p>\r\n<p>He is known to use cocaine and marijuana.</p>',
#    'height_max': 66,
#    'eyes_raw': 'Brown',
#    'uid': '46f36d741660405ab5d976b13b247913',
#    'age_range': None,
#    'nationality': 'American',
#    'dates_of_birth_used': ['November 1, 1978',
#     'January 1, 1978',
#     'January 11, 1978',
#     'June 21, 1979'],
#    'reward_text': None,
#    'aliases': ['"Ressi"', 'Fateh Ikram Sakkal', 'Reda Tahir', 'Rida Tahir'],
#    'height_min': 66,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/download.pdf'},
#     {'name': 'باللغة العربية',
#      'url': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher-9-4-18.pdf/@@download/file/Taher 9-4-18.pdf'}],
#    'race_raw': 'White',
#    'weight_min': 150,
#    'modified': '2021-11-16T14:59:44+00:00',
#    'legat_names': None,
#    'title': 'RODA ABDULHASSAN TAHER',
#    'weight': '150 to 190 pounds',
#    'publication': '2018-08-14T14:27:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': 'black',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Black, worn bald',
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/@@images/image/large',
#      'caption': 'Photograph taken in 2013'},
#     {'original': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher3.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher3.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher3.jpg/@@images/image/large',
#      'caption': 'Photograph taken in 2013'},
#     {'original': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher5.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher5.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher5.jpg/@@images/image/large',
#      'caption': 'Photograph taken circa 2008'},
#     {'original': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher6.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher6.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher6.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher2.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher2.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher2.jpg/@@images/image/large',
#      'caption': 'Photograph taken in 2013'},
#     {'original': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher4.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher4.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/roda-abdulhassan-taher/taher4.jpg/@@images/image/large',
#      'caption': 'Photograph taken in 2013'}],
#    'complexion': None,
#    'weight_max': 190,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': 'SHOULD BE CONSIDERED AN ESCAPE RISK',
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/46f36d741660405ab5d976b13b247913'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': None,
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['Seeking Information'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': None,
#    'ncic': None,
#    'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil',
#    'age_max': 52,
#    'path': '/wanted/seeking-info/ali-hage-zaki-jalil',
#    'possible_countries': None,
#    'description': 'Bombing of Alas Chiricanas Airlines Flight 00901\r\nJuly 19, 1994\r\nPanama',
#    'coordinates': [],
#    'remarks': '<p>Ali Hage Zaki Jalil was known to be an avid parachutist who traveled to multiple countries.\xa0 Jalil owned several bars on Margarita Island, Venezuela, and may have resided there.\xa0</p>',
#    'height_max': 70,
#    'eyes_raw': 'Brown',
#    'uid': '052b0a948f4344c9b2864e53f1b0c97f',
#    'age_range': 'Approximately 52 years old',
#    'nationality': None,
#    'dates_of_birth_used': None,
#    'reward_text': None,
#    'aliases': None,
#    'height_min': 70,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil_seeking_information.pdf'},
#     {'name': 'EN ESPAÑOL',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalilspanish.pdf/@@download/file/JalilSpanish.pdf'},
#     {'name': 'EM PORTUGUÊS',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil-portuguese-8-5x11-web-3.pdf/@@download/file/Jalil-Portuguese-8.5x11-web (3).pdf'},
#     {'name': 'باللغة العربية',
#      'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalilarabic-2.pdf/@@download/file/JalilARABIC (2).pdf'}],
#    'race_raw': None,
#    'weight_min': 200,
#    'modified': '2021-11-16T14:58:59+00:00',
#    'legat_names': None,
#    'title': 'ALI HAGE ZAKI JALIL',
#    'weight': 'Approximately 200 pounds',
#    'publication': '2020-07-28T11:03:00',
#    'status': 'na',
#    'race': None,
#    'hair': 'black',
#    'age_min': 52,
#    'suspects': None,
#    'hair_raw': 'Black',
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/@@images/image/large',
#      'caption': None},
#     {'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil_with_venezuelan_military-2014.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil_with_venezuelan_military-2014.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil_with_venezuelan_military-2014.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil-flying-2014.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil-flying-2014.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil-flying-2014.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil-formal-1.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil-formal-1.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil-formal-1.jpg/@@images/image/large',
#      'caption': ''}],
#    'complexion': None,
#    'weight_max': 200,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': '<p>Law enforcement officials are seeking information on the whereabouts of\xa0Ali Hage Zaki Jalil. It is believed that Jalil may have critical information pertaining to\xa0the bombing of Alas Chiricanas Airlines Flight 00901 on July 19, 1994.</p>\r\n<p>\xa0</p>\r\n<p>At approximately 4:30 p.m. Central Daylight Time (CDT), Flight 00901 departed from France Field, Colón, Panama, with a destination of Panama City, Panama. The flight exploded shortly after takeoff, killing all 21 people on board.\xa0Authorities are seeking information that may pertain to possible suspect(s) and the crime that occurred aboard this flight.</p>\r\n<p>\xa0</p>\r\n<p>All deceased passengers and crew in the Flight 00901 crash were claimed, except one. A body has possibly been identified as <a data-urltype="/view" data-linktype="external" href="https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal" data-val="https://www.fbi.gov/wanted/seeking-info/ali-hawa-jamal">Ali Hawa Jamal</a>. He is suspected of carrying the bomb aboard the aircraft.\xa0\xa0</p>',
#    '@id': 'https://api.fbi.gov/@wanted-person/052b0a948f4344c9b2864e53f1b0c97f'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Minnesota',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['Kidnappings and Missing Persons'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'green',
#    'caution': None,
#    'ncic': None,
#    'url': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert',
#    'age_max': None,
#    'path': '/wanted/kidnap/robert-craig-ehlert',
#    'possible_countries': None,
#    'description': 'June 2013\r\nPanama',
#    'coordinates': [],
#    'remarks': '<p>Ehlert is commonly known by his nickname "Bob" and\xa0has previously resided in Harris, Minnesota.</p>',
#    'height_max': 70,
#    'eyes_raw': 'Green',
#    'uid': '4c1eb3132d364884be9252f0091088d6',
#    'age_range': None,
#    'nationality': None,
#    'dates_of_birth_used': ['February 16, 1942'],
#    'reward_text': None,
#    'aliases': None,
#    'height_min': 70,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/download.pdf'},
#     {'name': 'EN ESPAÑOL',
#      'url': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/elhert-spanish-4-22-2021.pdf/@@download/file/Elhert Spanish 4-22-2021.pdf'}],
#    'race_raw': 'White',
#    'weight_min': 180,
#    'modified': '2021-11-16T14:58:16+00:00',
#    'legat_names': None,
#    'title': 'ROBERT CRAIG EHLERT',
#    'weight': '180 to 200 pounds',
#    'publication': '2021-04-07T14:30:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': 'brown',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Brown and gray',
#    'occupations': ['Retired - Finance'],
#    'images': [{'original': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/@@images/image/large',
#      'caption': 'Photograph taken in 2013'}],
#    'complexion': None,
#    'weight_max': 200,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': '<p>In June of 2013, Robert “Bob”\xa0Ehlert\xa0went missing in Panama.\xa0Ehlert\xa0was living in Panama at the time and was planning on sailing on his yacht around the world. He disappeared before the trip and has not been seen or heard from since.</p>',
#    '@id': 'https://api.fbi.gov/@wanted-person/4c1eb3132d364884be9252f0091088d6'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Sydney, Australia',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'blue',
#    'caution': '<p>Geoffrey John Busch is wanted for his alleged involvement in a scheme meant to defraud\xa0victim investors in Fort Lauderdale, Florida, from in or about September of 2002, through in or about early 2006.\xa0 The object of the conspiracy and scheme to defraud was to\xa0have the victim investors send money for "leased funds" to be placed in non-existent bank accounts which could be used in high-yield trading programs that could generate huge returns; divert all of the victim investor funds\xa0for Busch\'s\xa0own benefit; and perpetuate the scheme by continuing to misrepresent to victim investors that their investments were safe and that they had access to the funds in the created accounts.\xa0 Busch\'s\xa0alleged misrepresentations and false documents caused the victim investors to wire transfer funds to\xa0banks in\xa0the Bahamas.\xa0 He then allegedly failed to obtain leased funds,\xa0earn profits for any of the victim investors, or return the transferred funds to the victim investors.\xa0 When the victim investors sought a refund of their funds, Busch\xa0allegedly claimed\xa0that it was the victim investors\' fault that their money was not placed into a successful trade.\xa0 In the course of the scheme,\xa0Busch allegedly\xa0obtained over $12 million in\xa0proceeds from victim investors.</p>\r\n<p>\xa0</p>\r\n<p>Busch was indicted\xa0in the\xa0United States District Court, Southern District of Florida, Fort Lauderdale, Florida, and a federal warrant was issued for his arrest on December 18, 2007, after he was charged with conspiracy to commit wire fraud, wire fraud, and money laundering.</p>\r\n<p>\xa0</p>',
#    'ncic': 'W513806129',
#    'url': 'https://www.fbi.gov/wanted/wcc/geoffrey-john-busch',
#    'age_max': None,
#    'path': '/wanted/wcc/geoffrey-john-busch',
#    'possible_countries': None,
#    'description': 'Conspiracy to Commit Wire Fraud; Wire Fraud; Money Laundering',
#    'coordinates': [],
#    'remarks': '<p>Busch is believed to be residing in\xa0Australia.</p>',
#    'height_max': 72,
#    'eyes_raw': 'Blue',
#    'uid': '7e8b86c6de7b4cc2a1cdc22d4461b0f4',
#    'age_range': None,
#    'nationality': 'Australian',
#    'dates_of_birth_used': ['August 23, 1947'],
#    'reward_text': None,
#    'aliases': ['Geoffrey Busch'],
#    'height_min': 72,
#    'scars_and_marks': None,
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/geoffrey-john-busch/download.pdf'}],
#    'race_raw': 'White',
#    'weight_min': 180,
# ...
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/carlos-benitez/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/carlos-benitez/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/carlos-benitez/@@images/image/large',
#      'caption': 'Photograph taken in 2005'}],
#    'complexion': None,
#    'weight_max': 180,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/e3fea65939bd6028912b2e93baafac6c'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Cuba',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': '<p>Jose Benitez, <a data-urltype="/view" data-val="https://www.fbi.gov/wanted/wcc/carlos-benitez" href="https://www.fbi.gov/wanted/wcc/carlos-benitez" data-linktype="external">Carlos Benitez</a>, and <a data-urltype="/view" data-val="https://www.fbi.gov/wanted/wcc/luis-benitez" href="https://www.fbi.gov/wanted/wcc/luis-benitez" data-linktype="external">Luis Benitez</a> are wanted for their alleged involvement in a multi-million dollar scheme to defraud Medicare in the Miami-Dade area of Florida. It is alleged that from 2001 through 2004, the Benitez brothers, using straw owners to disguise their own involvement, owned and directed eleven medical clinics that purportedly provided HIV infusion treatment to infected Medicare beneficiaries. However, the medication that was alleged to have been given to the patients was medically unnecessary and often never given to the patients. The patients received kickbacks for their Medicare information. The Benitez brothers then allegedly opened sham companies to launder millions of dollars coming into the clinics from Medicare.</p>\r\n<p>\xa0</p>\r\n<p>On May 22, 2008, the Benitez brothers were indicted by a Federal Grand Jury for the United States District Court, Southern District of Florida, for conspiracy to defraud the United States, to cause the submission of false claims, and to pay health care kickbacks; conspiracy to commit health care fraud; submission of false claims; money laundering conspiracy; and money laundering. That same day, federal warrants were issued for their arrests.</p>',
#    'ncic': 'W514486351',
#    'url': 'https://www.fbi.gov/wanted/wcc/jose-benitez',
#    'age_max': None,
#    'path': '/wanted/wcc/jose-benitez',
#    'possible_countries': ['CUB', 'DMA', 'DOM', 'NIC', 'USA'],
#    'description': 'Conspiracy to Defraud the United States, to Cause the Submission of False Claims, and to Pay Health Care Kickbacks; Conspiracy to Commit Health Care Fraud; Submission of False Claims; Money Laundering Conspiracy; Money Laundering',
#    'coordinates': [],
#    'remarks': '<p>Jose Benitez may have travelled to Cuba, the Dominican Republic, and Nicaragua.</p>',
#    'height_max': 71,
#    'eyes_raw': 'Brown',
#    'uid': '4e956bd7292c3a844aea29c79833f975',
#    'age_range': None,
#    'nationality': 'Cuban',
#    'dates_of_birth_used': ['February 29, 1964'],
#    'reward_text': None,
#    'aliases': ['Jose Manuel Benitez',
#     'Jose Manuel Gonzalez',
#     'Jose Manuel Benitez Gonzalez'],
#    'height_min': 71,
#    'scars_and_marks': 'None known',
#    'possible_states': ['US-FL'],
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/jose-benitez/download.pdf'}],
#    'race_raw': 'White (Hispanic)',
#    'weight_min': 155,
#    'modified': '2021-11-16T14:57:07+00:00',
#    'legat_names': None,
#    'title': 'JOSE BENITEZ',
#    'weight': '155 pounds',
#    'publication': '2010-08-17T15:50:00',
#    'status': 'na',
#    'race': 'hispanic',
#    'hair': 'black',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Black',
#    'occupations': ['Businessman'],
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/jose-benitez/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/jose-benitez/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/jose-benitez/@@images/image/large',
#      'caption': 'Photograph taken in 2007'}],
#    'complexion': None,
#    'weight_max': 155,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/4e956bd7292c3a844aea29c79833f975'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'Cuba',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': '<p>Luis Benitez, <a data-urltype="/view" data-val="https://www.fbi.gov/wanted/wcc/carlos-benitez" href="https://www.fbi.gov/wanted/wcc/carlos-benitez" data-linktype="external">Carlos Benitez</a>, and <a data-urltype="/view" data-val="https://www.fbi.gov/wanted/wcc/jose-benitez" href="https://www.fbi.gov/wanted/wcc/jose-benitez" data-linktype="external">Jose Benitez </a>are wanted for their alleged involvement in a multi-million dollar scheme to defraud Medicare in the Miami-Dade area of Florida. It is alleged that from 2001 through 2004, the Benitez brothers, using straw owners to disguise their own involvement, owned and directed eleven medical clinics that purportedly provided HIV infusion treatment to infected Medicare beneficiaries. However, the medication that was alleged to have been given to the patients was medically unnecessary and often never given to the patients. The patients received kickbacks for their Medicare information. The Benitez brothers then allegedly opened sham companies to launder millions of dollars coming into the clinics from Medicare.</p>\r\n<p>\xa0</p>\r\n<p>On May 22, 2008, the Benitez brothers were indicted by a Federal Grand Jury for the United States District Court, Southern District of Florida, for conspiracy to defraud the United States, to cause the submission of false claims, and to pay health care kickbacks; conspiracy to commit health care fraud; submission of false claims; money laundering conspiracy; and money laundering. That same day, federal warrants were issued for their arrests.</p>',
#    'ncic': 'W484468798',
#    'url': 'https://www.fbi.gov/wanted/wcc/luis-benitez',
#    'age_max': None,
#    'path': '/wanted/wcc/luis-benitez',
#    'possible_countries': ['CUB', 'DOM', 'NIC', 'USA'],
#    'description': 'Conspiracy to Defraud the United States, to Cause the Submission of False Claims, and to Pay Health Care Kickbacks; Conspiracy to Commit Health Care Fraud; Submission of False Claims; Money Laundering Conspiracy; Money Laundering',
#    'coordinates': [],
#    'remarks': '<p>Luis Benitez injured his leg and walks with a limp. He may travel to Cuba, the Dominican Republic and Nicaragua.</p>',
#    'height_max': 71,
#    'eyes_raw': 'Brown',
#    'uid': '574e3cf3531d3fe1c7903a75a023209a',
#    'age_range': None,
#    'nationality': 'Cuban',
#    'dates_of_birth_used': ['June 6, 1966'],
#    'reward_text': None,
#    'aliases': ['Luis Enrique Gonzalez',
#     'Luis E. Benitez',
#     'Luis Enrique Benitez Gonzalez'],
#    'height_min': 71,
#    'scars_and_marks': 'None known',
#    'possible_states': ['US-FL'],
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/luis-benitez/download.pdf'}],
#    'race_raw': 'White (Hispanic)',
#    'weight_min': 180,
#    'modified': '2021-11-16T14:57:07+00:00',
#    'legat_names': None,
#    'title': 'LUIS BENITEZ',
#    'weight': '180 pounds',
#    'publication': '2010-08-12T19:35:00',
#    'status': 'na',
#    'race': 'hispanic',
#    'hair': 'black',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Black',
#    'occupations': ['Businessman'],
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/luis-benitez/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/luis-benitez/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/luis-benitez/@@images/image/large',
#      'caption': 'Photograph taken in 2005'}],
#    'complexion': None,
#    'weight_max': 180,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/574e3cf3531d3fe1c7903a75a023209a'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': None,
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'blue',
#    'caution': None,
#    'ncic': 'W648052561',
#    'url': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn',
#    'age_max': None,
#    'path': '/wanted/wcc/john-anthony-quinn',
#    'possible_countries': None,
#    'description': 'Unlawful Flight to Avoid Prosecution - First Degree Grand Theft',
#    'coordinates': [],
#    'remarks': '<p>Quinn is known to have ties\xa0to Maryland.</p>',
#    'height_max': 68,
#    'eyes_raw': 'Blue',
#    'uid': '9f1ad7ac37a84797a3d29f47b4cda8aa',
#    'age_range': None,
#    'nationality': None,
#    'dates_of_birth_used': ['January 7, 1940', 'June 26, 1952'],
#    'reward_text': None,
#    'aliases': ['Dale Calvin Cluckey, Dale Clucke, Jack Quinn, James Sullivan'],
#    'height_min': 68,
#    'scars_and_marks': 'Quinn has a "U.S. Marine style" tattoo on his left bicep and a scar on the back of his neck.',
#    'possible_states': None,
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/download.pdf'}],
#    'race_raw': 'White',
#    'weight_min': 225,
#    'modified': '2021-11-16T14:56:46+00:00',
#    'legat_names': None,
#    'title': 'JOHN ANTHONY QUINN',
#    'weight': '225 pounds',
#    'publication': '2016-11-08T12:23:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': 'brown',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Brown',
#    'occupations': None,
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/@@images/image/large',
#      'caption': 'Photograph taken in the 1980s'},
#     {'original': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn-1-09-06-16.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn-1-09-06-16.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn-1-09-06-16.jpg/@@images/image/large',
#      'caption': 'Age progressed photographs to 76 years old'},
#     {'original': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn-beard-1-09-06-16.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn-beard-1-09-06-16.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn-beard-1-09-06-16.jpg/@@images/image/large',
#      'caption': 'Age progressed photographs to 76 years old.'},
#     {'original': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn2.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn2.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinn2.jpg/@@images/image/large',
#      'caption': ''},
#     {'original': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinntattoo.jpg',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinntattoo.jpg/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/john-anthony-quinn/quinntattoo.jpg/@@images/image/large',
#      'caption': ''}],
#    'complexion': None,
#    'weight_max': 225,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': None,
#    'details': "<p>John Anthony Quinn is wanted for his alleged involvement in the theft of $1.3 million in cash from Federal Protection Service, an armored car service\xa0in Riviera Beach, Florida, in April of 1988. Quinn was employed as the manager and is alleged to have stolen the money from the company's\xa0vault. On April 12, 1988, the state of Florida, in and for Palm Beach County, Florida, issued an arrest warrant for Quinn on one count of Grand Theft. A federal arrest warrant was issued for Quinn in the United States District Court, Southern District of Florida, on June 21, 1988, after\xa0he\xa0was charged with\xa0Unlawful Flight to Avoid Prosecution. \xa0</p>",
#    '@id': 'https://api.fbi.gov/@wanted-person/9f1ad7ac37a84797a3d29f47b4cda8aa'},
#   {'locations': None,
#    'reward_min': 0,
#    'place_of_birth': 'New York',
#    'reward_max': 0,
#    'additional_information': None,
#    'subjects': ['White-Collar Crime'],
#    'languages': None,
#    'sex': 'Male',
#    'eyes': 'brown',
#    'caution': "<p>John Anthony Porcaro is wanted for his alleged involvement in a South Florida telemarketing scheme which defrauded more than 400 individuals throughout the United States out of more than $5 million. Between February and December of 1998, the Trump Financial Group and the Sheffield Group were doing business as telemarketing firms which obtained money from investors for purported investment in foreign currency options in the foreign exchange markets. It is alleged that investors were promised as much as 700 percent returns based upon the rise and fall of the value of foreign currencies in relation to the value of the United States Dollar.</p>\r\n<p>\xa0</p>\r\n<p>Investors rarely, if ever, received returns on their investments and money raised from investors allegedly was used for the personal benefit of the firms' principal employees and telemarketers who sold investments. A substantial amount of the money also was transferred to offshore bank accounts in the Cayman Islands.</p>\r\n<p>\xa0</p>\r\n<p>On October 21, 2003, a federal indictment was filed by the United States District Court, Southern District of Florida, charging Porcaro, and others who are no longer at large, with multiple counts of wire fraud, mail fraud, and money laundering. A federal warrant remains outstanding for the arrest of Porcaro.</p>",
#    'ncic': 'W295378385',
#    'url': 'https://www.fbi.gov/wanted/wcc/john-anthony-porcaro',
#    'age_max': None,
#    'path': '/wanted/wcc/john-anthony-porcaro',
#    'possible_countries': ['USA'],
#    'description': 'Conspiracy to Commit Mail and Wire Fraud; Conspiracy to Commit Money Laundering',
#    'coordinates': [],
#    'remarks': '<p>Porcaro is an alleged associate of the Gambino crime family in New York.</p>',
#    'height_max': 68,
#    'eyes_raw': 'Brown',
#    'uid': '0d8ce11baaed80cf362c08f7aff73cf6',
#    'age_range': None,
#    'nationality': 'American',
#    'dates_of_birth_used': ['June 16, 1959'],
#    'reward_text': 'The FBI is offering a reward for information leading to the arrest of John Anthony Porcaro.',
#    'aliases': ['John A. Porcaro'],
#    'height_min': 68,
#    'scars_and_marks': 'Porcaro has an artificial right eye and a scar above his left eye.',
#    'possible_states': ['US-FL', 'US-NY'],
#    'field_offices': ['miami'],
#    'files': [{'name': 'English',
#      'url': 'https://www.fbi.gov/wanted/wcc/john-anthony-porcaro/download.pdf'}],
#    'race_raw': 'White',
#    'weight_min': 197,
#    'modified': '2021-11-16T14:56:45+00:00',
#    'legat_names': None,
#    'title': 'JOHN ANTHONY PORCARO',
#    'weight': '197 pounds',
#    'publication': '2010-08-17T17:15:00',
#    'status': 'na',
#    'race': 'white',
#    'hair': 'brown',
#    'age_min': None,
#    'suspects': None,
#    'hair_raw': 'Brown',
#    'occupations': ['Moving company owner'],
#    'images': [{'original': 'https://www.fbi.gov/wanted/wcc/john-anthony-porcaro/@@images/image',
#      'thumb': 'https://www.fbi.gov/wanted/wcc/john-anthony-porcaro/@@images/image/thumb',
#      'large': 'https://www.fbi.gov/wanted/wcc/john-anthony-porcaro/@@images/image/large',
#      'caption': 'Photograph taken in 1989'}],
#    'complexion': None,
#    'weight_max': 197,
#    'person_classification': 'Main',
#    'build': None,
#    'warning_message': 'SHOULD BE CONSIDERED ARMED AND DANGEROUS',
#    'details': None,
#    '@id': 'https://api.fbi.gov/@wanted-person/0d8ce11baaed80cf362c08f7aff73cf6'}],
#  'page': 1}

# %% [markdown]
# ---
